# %%
import pandas as pd
matches=pd.read_csv(r"C:\Users\Haritha\Desktop\matches.csv")
matches
# Out:
#       id  season           city       date                        team1  \
# 0      1    2017      Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1      2    2017           Pune   4/6/2017               Mumbai Indians
# 2      3    2017         Rajkot   4/7/2017                Gujarat Lions
# 3      4    2017         Indore   4/8/2017       Rising Pune Supergiant
# 4      5    2017      Bangalore   4/8/2017  Royal Challengers Bangalore
# 5      6    2017      Hyderabad   4/9/2017                Gujarat Lions
# 6      7    2017         Mumbai   4/9/2017        Kolkata Knight Riders
# 7      8    2017         Indore  4/10/2017  Royal Challengers Bangalore
# 8      9    2017           Pune  4/11/2017             Delhi Daredevils
# 9     10    2017         Mumbai  4/12/2017          Sunrisers Hyderabad
# 10    11    2017        Kolkata  4/13/2017              Kings XI Punjab
# 11    12    2017      Bangalore  4/14/2017  Royal Challengers Bangalore
# ...

# %%
df.shape[0]
# Out:
# 636

# %%
#DL
dl=matches[matches['dl_applied']==1]
dl
# Out:
#       id  season           city       date                        team1  \
# 56    57    2017      Bangalore  5/17/2017          Sunrisers Hyderabad
# 99   100    2008          Delhi  5/17/2008             Delhi Daredevils
# 102  103    2008        Kolkata  5/18/2008        Kolkata Knight Riders
# 119  120    2009      Cape Town  4/19/2009              Kings XI Punjab
# 122  123    2009         Durban  4/21/2009              Kings XI Punjab
# 148  149    2009      Centurion   5/7/2009          Chennai Super Kings
# 251  252    2011          Kochi  4/18/2011          Chennai Super Kings
# 280  281    2011        Kolkata   5/7/2011          Chennai Super Kings
# 290  291    2011      Bangalore  5/14/2011        Kolkata Knight Riders
# 488  489    2014          Delhi  5/10/2014             Delhi Daredevils
# 536  537    2015  Visakhapatnam  4/22/2015          Sunrisers Hyderabad
# 567  568    2015      Hyderabad  5/15/2015          Sunrisers Hyderabad
# ...

# %%
#1
win_count= matches[matches['toss_winner']==matches['winner']]
count_var=win_count['winner'].value_counts()
print(count_var)
# Out:
# Mumbai Indians                 48
# Kolkata Knight Riders          44
# Chennai Super Kings            42
# Royal Challengers Bangalore    35
# Rajasthan Royals               34
# Delhi Daredevils               33
# Kings XI Punjab                28
# Deccan Chargers                19
# Sunrisers Hyderabad            17
# Gujarat Lions                  10
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Pune Warriors                   3
# Name: winner, dtype: int64

# %%
losers_count= matches[matches['toss_winner']!=matches['winner']]
coun_var=losers_count['winner'].value_counts()
print(coun_var)
# Out:
# Mumbai Indians                 44
# Kings XI Punjab                42
# Royal Challengers Bangalore    38
# Chennai Super Kings            37
# Kolkata Knight Riders          33
# Delhi Daredevils               29
# Rajasthan Royals               29
# Sunrisers Hyderabad            25
# Deccan Chargers                10
# Pune Warriors                   9
# Rising Pune Supergiant          5
# Gujarat Lions                   3
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Name: winner, dtype: int64

# %%
total_count=count_var+coun_var
per=count_var/total_count*100
print("there is only",per.median(),"chance of winning the match over toss")
# Out:
# there is only 53.1951817068191 chance of winning the match over toss

# %%
import pandas as pd
cf=pd.read_csv(r"C:\Users\Haritha\Desktop\deliveries.csv")
cf
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
cf.shape[0]
# Out:
# 150460

# %%
#2
wicket_takers=cf[cf['player_dismissed'].isnull()==False]
wicket_t= wicket_takers['bowler'].value_counts()
wicket_t.head(10)
# Out:
# SL Malinga         170
# A Mishra           142
# DJ Bravo           137
# Harbhajan Singh    136
# PP Chawla          133
# R Vinay Kumar      125
# A Nehra            121
# Z Khan             119
# B Kumar            117
# R Ashwin           110
# Name: bowler, dtype: int64

# %%
total_balls=cf['batsman'].value_counts()
total_balls
# Out:
# 0    61148
# 1    55497
# 4    17033
# 2     9705
# 6     6523
# 3      509
# 5       45
# Name: batsman_runs, dtype: int64

# %%
condition=(cf['wide_runs']==0)
balls=cf[condition]
d=balls['batsman'].value_counts()
head=d.head(19)
head
# Out:
# V Kohli           3405
# G Gambhir         3316
# SK Raina          3267
# RG Sharma         3214
# S Dhawan          2922
# RV Uthappa        2870
# DA Warner         2825
# MS Dhoni          2604
# AM Rahane         2535
# CH Gayle          2409
# AB de Villiers    2348
# KD Karthik        2305
# JH Kallis         2222
# BB McCullum       2102
# M Vijay           2035
# YK Pathan         2000
# PA Patel          1981
# Yuvraj Singh      1974
# SR Tendulkar      1948
# Name: batsman, dtype: int64

# %%
g=cf['batsman']
c=cf.groupby(['batsman']).sum()
t=c['batsman_runs']

t
# Out:
# batsman
# A Ashish Reddy           280
# A Chandila                 4
# A Chopra                  53
# A Choudhary               25
# A Flintoff                62
# A Kumble                  35
# A Mishra                 340
# A Mithun                  34
# A Mukund                  19
# A Nehra                   41
# A Singh                    2
# A Symonds                974
# A Uniyal                   4
# A Zampa                    5
# AA Bilakhia               69
# AA Chavan                 12
# AA Jhunjhunwala          217
# AA Noffke                  9
# AB Agarkar               179
# AB Barath                 42
# AB Dinda                  26
# AB McDonald              123
# AB de Villiers          3486
# AC Blizzard              120
# AC Gilchrist            2069
# AC Thomas                 20
# AC Voges                 181
# AD Mascarenhas            79
# AD Mathews               724
# AD Nath                   20
#                         ...
# ...

# %%
#Top 5 run scoring batsman
w=t.sort_values(ascending=False).head(5)
w
# Out:
# batsman
# SK Raina     4548
# V Kohli      4423
# RG Sharma    4207
# G Gambhir    4132
# DA Warner    4014
# Name: batsman_runs, dtype: int64

# %%
#strike rate
r=(t/head)*100
r.sort_values(ascending=False).head()
# Out:
# CH Gayle          151.556663
# AB de Villiers    148.466780
# YK Pathan         146.100000
# DA Warner         142.088496
# SK Raina          139.210285
# dtype: float64

# %%
dl_1 = matches[matches['dl_applied'] == 1]
B=set(list(dl_1.team1.unique()) + list(dl_1.team2.unique()))
B
# Out:
# {'Chennai Super Kings',
#  'Delhi Daredevils',
#  'Kings XI Punjab',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad'}

# %%
dl_2=matches[matches.dl_applied.notnull()]
A=set(list(dl_2.team1.unique()) + list(dl_2.team2.unique()))
A
# Out:
# {'Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Daredevils',
#  'Gujarat Lions',
#  'Kings XI Punjab',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Pune Warriors',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad'}

# %%
#DL
C=A-B
C
# Out:
# {'Deccan Chargers',
#  'Gujarat Lions',
#  'Mumbai Indians',
#  'Pune Warriors',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant'}

# %%
#venue and team wise toss decision
gfa=matches.groupby(['venue', 'toss_decision']).size()
gfa
# Out:
# venue                                                 toss_decision
# Barabati Stadium                                      bat               2
#                                                       field             5
# Brabourne Stadium                                     bat               6
#                                                       field             5
# Buffalo Park                                          bat               3
# De Beers Diamond Oval                                 bat               2
#                                                       field             1
# Dr DY Patil Sports Academy                            bat               7
#                                                       field            10
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium   bat               5
#                                                       field             6
# Dubai International Cricket Stadium                   bat               3
# ...

# %%
s=matches.toss_winner.value_counts()
s
# Out:
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
matches.groupby(['toss_winner','toss_decision']).size()
# Out:
# toss_winner                  toss_decision
# Chennai Super Kings          bat              44
#                              field            22
# Deccan Chargers              bat              24
#                              field            19
# Delhi Daredevils             bat              26
#                              field            46
# Gujarat Lions                bat               1
#                              field            14
# Kings XI Punjab              bat              25
#                              field            43
# Kochi Tuskers Kerala         bat               3
#                              field             5
# Kolkata Knight Riders        bat              30
#                              field            48
# Mumbai Indians               bat              40
#                              field            45
# Pune Warriors                bat              11
#                              field             9
# ...
